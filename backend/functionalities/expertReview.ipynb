# %%
from bs4 import BeautifulSoup
import requests

# %%
query = 'Samsung M 34'
url="https://www.gsmarena.com/samsung_galaxy_s24-review-2663.php"
headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.text)
# Out:
# Samsung Galaxy S24 review - GSMArena.com tests
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# GSMArena.com
#
#
#
#
#
#
#
#
#
#
#
#
# Tip us
#
#
#
# 1.7m
#
#
# 126k
#
#
# RSS
#
#
# EV
#
#
# Merch
#
#
#
#
# Log in
#
#
#
#
# Login
#
#
#
#
#
#
# I forgot my password
#
# Sign up
#
#
#
# Home
# News
# Reviews
# Videos
# Featured
# Phone Finder
# Deals
# MerchNew
# Coverage
# Contact
#
#
#
#
#
#
#
#
# ADVERTISEMENT
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# GSMArena Team,
#     01 February 2024
#
#
#
#
# Samsung Galaxy S24 review
#
#
#
#
#
# Comments (87)
# User reviews
# Galaxy S24
#
#
#
# 4.4
#
#
#
#
#
#
#
#
#
#
# 1. Introduction, specs, unboxing
#
#
# 1. Introduction, specs, unboxing2. Design, build quality, handling3. Our lab tests - display, battery life, charging speed, speakers4. Software and performance5. Camera, photo and video quality6. Final words, our verdict, pros and cons  Samsung Galaxy S24 specificationUser opinions and reviewsReview comments (87)
#
#
#
#
#
#
#
# Samsung Android
#
#
#
#
# Pricing
#
#
# These are the best offers from our affiliate partners. We may get a commission from qualifying sales.
#
#
#
#
#
# 128GB 8GB RAM
# $ 799.99
# $ 799.99
#
#
# 256GB 8GB RAM
# ₹ 74,999
# $ 799.99
#
#
# 512GB 8GB RAM
# ₹ 89,999
#
#
#
# Show all prices
#
#
# Introduction
# The Galaxy S24 series has finally launched after numerous rumors, speculations and daily leaks. And the trio is what we expected - a solid but incremental update over the S23 models. Today, we will be exploring the runt of the next generation Galaxy phones, the smallest of the bunch, and Galaxy mini, if you will - the Galaxy S24.
# Quick note - we are reviewing the Exynos model of the Galaxy S24 here.
#
# The new Galaxy S24 introduces a refreshed, refined, even design, with flat Victus 2 panels and a flat aluminum frame with a new matte finish. The Galaxy S24 keeps the same size as the S23, but thanks to the LTPO screen panels, it manages to fit an even larger 6.2-inch display with thinner bezels into the same space.
# And that is the first upgrade - the Galaxy S24 now comes with a 6.2-inch LTPO Dynamic AMOLED 2x with extended 1080p resolution and 120Hz refresh rate. It has 2,600nits of peak brightness, up from 1,750 on the S23.
#
#
#
#
# Left: Galaxy S24 • Right: Galaxy S23
# The chipset upgrade is the next improvement, and the hardware fragmentation is back! The S24 employs the Exynos 2400 chipset in most markets with a 10-core CPU and a new AMD GPU, while the US, Canada and China get it with the Snapdragon 8 Gen 3 SoC. The S24 has two storage versions for the global model - 128GB UFS 3.1 and 256GB UFS 4.0, both with 8GB RAM. There is a limited 512GB version in some countries, too.
#
# Left: Galaxy S24+ • Right: Galaxy S24
# The entire camera kit has been lifted from the S23. There are three imagers at the back - a 50MP OIS primary, a 10MP 3x tele, and a 12MP ultrawide. A 12MP front camera with autofocus will take care of selfie capture.
#
# Left: Galaxy S24+ • Right: Galaxy S24
# The battery capacity has increased from 3,900mAh to 4,000mAh, while the charging capabilities remain the same - 25W wired, 15W wireless, and 4.5W reverse wireless.
# Here is the complete specs sheet.
# Samsung Galaxy S24 specs at a glance:
#
# Body: 147.0x70.6x7.6mm, 167g; Glass front (Gorilla Glass Victus 2), glass back (Gorilla Glass Victus 2), aluminum frame; IP68 dust/water resistant (up to 1.5m for 30 min), Armor aluminum 2 frame with tougher drop and scratch resistance (advertised).
# Display: 6.20" Dynamic LTPO AMOLED 2X, 120Hz, HDR10+, 2600 nits (peak), 1080x2340px resolution, 19.5:9 aspect ratio, 416ppi; Always-on display.
# Chipset: Qualcomm SM8650-AC Snapdragon 8 Gen 3 (4 nm) - USA/Canada/China, Exynos 2400 (4 nm) - International: 8-core (1x3.39GHz Cortex-X4 & 3x3.1GHz Cortex-A720 & 2x2.9GHz Cortex-A720 & 2x2.2GHz Cortex-A520), 10-core (1x3.2GHz Cortex-X4 & 2x2.9GHz Cortex-A720 & 3x2.6GHz Cortex-A720 & 4x1.95GHz Cortex-A520); Adreno 750 (1 GHz) - USA/Canada/China, Xclipse 940 - International.
# Memory: 128GB 8GB RAM, 256GB 8GB RAM, 256GB 12GB RAM, 512GB 8GB RAM; UFS 3.1 - 128GB only, UFS 4.0.
# OS/Software: Android 14, One UI 6.1.
# Rear camera: Wide (main): 50 MP, f/1.8, 24mm, 1/1.56", 1.0µm, Dual Pixel PDAF, OIS; Telephoto: 10 MP, f/2.4, 67mm, 1/3.94", 1.0µm, PDAF, OIS, 3x optical zoom; Ultra wide angle: 12 MP, f/2.2, 13mm, 120-degree, 1/2.55" 1.4µm, Super Steady video.
# Front camera: 12 MP, f/2.2, 26mm (wide), Dual Pixel PDAF.
# Video capture: Rear camera: 8K@24/30fps, 4K@30/60fps, 1080p@30/60/240fps, 1080p@960fps, HDR10+, stereo sound rec., gyro-EIS; Front camera: 4K@30/60fps, 1080p@30fps.
# Battery: 4000mAh; 25W wired, PD3.0, 50% in 30 min (advertised), 15W wireless (Qi/PMA), 4.5W reverse wireless.
# Connectivity: 5G; eSIM; Dual SIM; Wi-Fi 6e; BT 5.3; NFC.
# Misc: Fingerprint reader (under display, ultrasonic); stereo speakers; Samsung DeX, Samsung Wireless DeX (desktop experience support).
# The Galaxy S24 base version is still 128GB - something we hoped Samsung would drop as there are no UFS 4.0 chips for this capacity. This model still has no Ultra Wideband, and the charging is still limited to 25W. None of these is a deal breaker, but they would have sat nicely as small upgrades on the spec sheet.
# Unboxing the Samsung Galaxy S24
# The eco-friendly retail box is here to stay, of course. The Galaxy S24 bundle contains a 3A USB-C-C cable and a SIM ejection tool.
# And that's all.
#
# At least the pre-order campaign for the Galaxy S24 included a 25W fast charger and a clear, transparent case. Even better, Samsung was selling the 256GB model at the price of the 128GB one to those who had pre-ordered.
#
#
# Next Page »
# 2. Design, build quality, handling
#
#
#
#
#
# 1. Introduction, specs, unboxing
#
#
# 1. Introduction, specs, unboxing2. Design, build quality, handling3. Our lab tests - display, battery life, charging speed, speakers4. Software and performance5. Camera, photo and video quality6. Final words, our verdict, pros and cons  Samsung Galaxy S24 specificationUser opinions and reviewsReview comments (87)
#
#
#
#
#
#
#
# Reviews
#
# Samsung Galaxy S24 review
#
#
#
# Comments (87)
# User reviews
# Galaxy S24
#
#
#
#
# Samsung Galaxy S24 review - Reader comments
#
# M
# MANU
#
#
# 3CK
# 3 hours ago
#
# I just bought a S24 to replace my S8.
# It is only this month that I started to see applications that cannot be upgraded or installed because the Android version is not supported anymore. Also, I had to switch to Brave to navigate on the Internet. O...
#
#
#
# Reply
#
#
#
#
# d
# disfunktor
#
#
# pr0
# 3 hours ago
#
# Why are all reviews ignoring non-funcitional Vivid mode, and in general unprecise and washed out colors. And in some cases grainy and greyish blacks?
#
#
#
# Reply
#
#
#
#
# S
# Smallworld
#
#
# JgF
# 3 hours ago
#
# If they reviewed the 128Gb version, that could explain why the antutu scores are slighly lower than the S24+
#
#
#
# Reply
#
#
#
#
#
#
# Read all comments
# Post your comment
#
#
# Total reader comments: 87
#
#
#
#
#
#
#
#
#
# Phone finder
#
#
# SamsungAppleHuaweiNokiaSonyLGHTCMotorolaLenovoXiaomiGoogleHonorOppoRealmeOnePlusvivoMeizuBlackBerryAsusAlcatelZTEMicrosoftVodafoneEnergizerCatSharpMicromaxInfinixUlefoneTecnoDoogeeBlackviewCubotOukitelItelTCL
#
#
#
# All brands
#
#
#
# Rumor mill
#
#
#
#
# ADVERTISEMENT
#
#
#
#
# Related articles
#
#
#
#
# Samsung Spain denies a change to Galaxy S24 vivid mode is coming
#
#
#
#
#
# Samsung Galaxy Ring pops up in the Good Lock app
#
#
#
#
#
# Codename for Samsung’s rumored affordable foldable leaks
#
#
#
#
#
# Samsung acknowledges Galaxy S24 display color issues, fix incoming
#
#
#
#
# ADVERTISEMENT
#
#
#
#
#
# Popular reviews
#
#
#
# Samsung Galaxy S24 Ultra, S24+ and S24 hands-on review
#
#
#
#
#
# OnePlus 12 review
#
#
#
#
#
# Infinix Hot 40 Pro review
#
#
#
#
#
# ELECTRIC VEHICLES
#
#
#
# Tesla Cybertruck's aerodynamic wheel covers found to damage tires
# Mini Aceman is coming on April 24 with choice of 2 motors and 3 trimsWinter range test of 23 EVs produces surprising champion
#
#
# ADVERTISEMENT
#
#
#
#
#
#
#
#
#
#
#
#
# Home
# News
# Reviews
# Compare
# Coverage
# Glossary
# FAQ
# RSS feed
# Youtube
# Facebook
# Twitter
# Instagram
#
#
# © 2000-2024 GSMArena.com
# Mobile version
# Android app
# Tools
# Contact us
# Merch store
# Privacy
# Terms of use
# Change Ad Consent
# Do not sell my data

# %%
review_websites = {
    'all': [
        {
            'name': 'tomsguide',
            'pattern': "https://www.tomsguide.com/reviews/{}",
            'review_tree': {
                'element': 'p',
                'attrs': {'class': 'pretty-verdict'}
            }
        },
    ],
    'phones': [
        {
            'name': 'gsmarena',
            'pattern': "https://www.gsmarena.com/{}-reviews-{}.php",
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'uopin'}
            }
        },
        {
            'name': 'techradar',
            'pattern': "https://www.techradar.com/reviews/phones/{}",
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'pretty-verdict'}
            
            }
        },
        {
            'name': 'digit',
            'pattern': "https://www.digit.in/reviews/{}",
            'review_tree': {
                'element': 'article',
            }
        },
        {
            'name': 'cnbctv',
            'pattern': "https://www.cnbctv18.com/technology/{}",
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'narticle-text'}
            }
        },
        {
          'name': 'gadgets360',
          'pattern': 'https://www.gadgets360.com/mobiles/reviews/{}',
          'review_tree': {
                'element': 'div',
                'attrs': {'class': 'content_text'}
            }
        },
    ],
    'laptops': [
        {
            'name': 'theverge',
            'pattern': "https://www.theverge.com/laptop-review/{}",
            'review_tree': {
                'element': 'aside'
            }
        },
        {
            'name': 'pcmag',
            'pattern': "https://www.pcmag.com/reviews/{}",
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'pros-cons'}
            }
        },
        {
            'name': 'laptopmag',
            'pattern': "https://www.laptopmag.com/reviews/{}",
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'pretty-verdict'}
            }
        }
    ],
    'shoes': [
        {
            'name': 'shoesguidance',
            'pattern': 'https://shoesguidance.com/{}',
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'entry-content'}
            }            
        },
        {
            'name': 'soleracks',
            'pattern': 'https://soleracks.com/{}',
            'review_tree': {
                'element': 'div',
                'attrs': {'class': 'fusion-content-boxes'}
            }
        }
    ]
}

# %%
url = review_websites['phones'][1]['pattern'].format('samsung-galaxy-s24-ultra')

# %%
# url="https://www.gsmarena.com/samsung_galaxy_s24-review-2663.php"
headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36"
}
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.find_all('div', class_='pretty-verdict')
# Out:
# []

# %%
query_product_name = 'Samsung Galaxy S24 Ultra'

# %%
# all_sites = [website['name'] for website in review_websites['phones']] + [website['name'] for website in review_websites['all']]
# all_sites = ' , '.join(all_sites)
google_search = f'https://www.googleapis.com/customsearch/v1?key={google_api_key}&cx=16bf42430283e4cb5&q={query_product_name}&exactTerms=review'

# %%
google_search
# Out:
# 'https://www.googleapis.com/customsearch/v1?key=AIzaSyDVCg8RYgaL3JLHX7tK7QJ2plozN-W2hQM&cx=16bf42430283e4cb5&q=Samsung Galaxy S24 Ultra&exactTerms=review'

# %%
google_search_response = requests.get(google_search)

# %%
google_search_response.json()
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - Samsung Galaxy S24 Ultra',
#     'totalResults': '25400',
#     'searchTerms': 'Samsung Galaxy S24 Ultra',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '16bf42430283e4cb5',
#     'exactTerms': 'review'}],
#   'nextPage': [{'title': 'Google Custom Search - Samsung Galaxy S24 Ultra',
#     'totalResults': '25400',
#     'searchTerms': 'Samsung Galaxy S24 Ultra',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '16bf42430283e4cb5',
#     'exactTerms': 'review'}]},
#  'context': {'title': 'DPBH'},
#  'searchInformation': {'searchTime': 0.477583,
#   'formattedSearchTime': '0.48',
#   'totalResults': '25400',
#   'formattedTotalResults': '25,400'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S24 Ultra Review | PCMag',
#    'htmlTitle': '<b>Samsung Galaxy S24 Ultra Review</b> | PCMag',
#    'link': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-ultra',
#    'displayLink': 'www.pcmag.com',
#    'snippet': 'Jan 25, 2024 ... Samsung Galaxy S24 Ultra Review ; The Bottom Line. With a refined design, tons of power, a built-in stylus, helpful AI tools, and seven years of\xa0...',
#    'htmlSnippet': 'Jan 25, 2024 <b>...</b> <b>Samsung Galaxy S24 Ultra Review</b> ; The Bottom Line. With a refined design, tons of power, a built-in stylus, helpful AI tools, and seven years of&nbsp;...',
#    'cacheId': 'bl3Kt0qswJ4J',
#    'formattedUrl': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-ultra',
#    'htmlFormattedUrl': 'https://www.pcmag.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-<b>s24</b>-<b>ultra</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSsVqUzNYSRNplPZsN-8__Q2gdt9bOMUrYFFBan60TAl1uW5yXMY73xv2Te',
#       'width': '299',
#       'height': '168'}],
#     'metatags': [{'application-name': 'PCMag',
#       'og:image': 'https://i.pcmag.com/imagery/reviews/02LTC7buGUIxi5VB9YVcSCU-1.fit_lim.size_1200x630.v1706040657.jpg',
#       'og:type': 'article',
#       'og:image:width': '1200',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Samsung Galaxy S24 Ultra Review',
#       'og:site_name': 'PCMAG',
#       'twitter:url': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-ultra',
#       'og:title': 'Samsung Galaxy S24 Ultra Review',
#       'og:image:height': '630',
#       'og:description': 'With a refined design, tons of power, a built-in stylus, helpful AI tools, and seven years of promised updates, the Samsung Galaxy S24 Ultra is one of the best Android phones you can buy for the long haul.',
#       'twitter:image': 'https://i.pcmag.com/imagery/reviews/02LTC7buGUIxi5VB9YVcSCU-1.fit_lim.size_1200x630.v1706040657.jpg',
#       'zd_ptax_version': 'PCMagV3',
#       'fb:app_id': '141810985954037',
#       'twitter:site': '@pcmag',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': 'With a refined design, tons of power, a built-in stylus, helpful AI tools, and seven years of promised updates, the Samsung Galaxy S24 Ultra is one of the best Android phones you can buy for the long haul.',
#       'zd_ptax': 'samsung,computers-electronics,mobile-phones',
#       'og:url': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-ultra',
#       'twitter:account_id': '15066271'}],
#     'cse_image': [{'src': 'https://i.pcmag.com/imagery/reviews/02LTC7buGUIxi5VB9YVcSCU-1.fit_lim.size_1200x630.v1706040657.jpg'}],
#     'listitem': [{'item': 'Home', 'name': 'Home', 'position': '1'},
#      {'item': 'Reviews', 'name': 'Reviews', 'position': '2'},
#      {'item': 'Mobile Phones', 'name': 'Mobile Phones', 'position': '3'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S24 Ultra, Galaxy S24+, and Galaxy S24 First ...',
#    'htmlTitle': '<b>Samsung Galaxy S24 Ultra</b>, Galaxy S24+, and Galaxy <b>S24</b> First ...',
#    'link': 'https://www.gadgets360.com/mobiles/reviews/samsung-galaxy-s24-ultra-plus-series-price-in-india-first-look-camera-specifications-4878627',
#    'displayLink': 'www.gadgets360.com',
#    'snippet': "Jan 18, 2024 ... Samsung Galaxy S24 Ultra · Giottus · Samsung Galaxy Z Flip 5 · Apple 'Scary Fast' · Housefull 5 · GoPro Hero 12 Black Review · Invincible Season\xa0...",
#    'htmlSnippet': 'Jan 18, 2024 <b>...</b> <b>Samsung Galaxy S24 Ultra</b> &middot; Giottus &middot; <b>Samsung Galaxy</b> Z Flip 5 &middot; Apple &#39;Scary Fast&#39; &middot; Housefull 5 &middot; GoPro Hero 12 Black <b>Review</b> &middot; Invincible Season&nbsp;...',
#    'cacheId': '8yaIOUOZHPIJ',
#    'formattedUrl': 'https://www.gadgets360.com/.../reviews/samsung-galaxy-s24-ultra-plus-seri...',
#    'htmlFormattedUrl': 'https://www.gadgets360.com/.../<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-<b>s24</b>-<b>ultra</b>-plus-seri...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRKPwJmnjtF1VpTF-1xj5Xst-cebMzlOaLKy22ThFp2vjEyMzM_aBRrrej4',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'twitter:app:id:googleplay': 'com.ndtv.gadgets',
#       'og:image': 'https://i.gadgets360cdn.com/large/samsung-galaxys24-ultra_1705477612346.jpg',
#       'apple-itunes-app': 'app-id=620437614',
#       'theme-color': '#da0000',
#       'article:published_time': '2024-01-17T23:45:22+05:30',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Gadgets 360',
#       'al:android:package': 'com.ndtv.gadgets',
#       'twitter:app:name:googleplay': 'Gadgets 360',
#       'twitter:app:id:iphone': '620437614',
#       'og:description': 'Can Samsung redefine the flagship smartphone experience with AI?',
#       'twitter:creator': 'https://twitter.com/harry_jerry',
#       'twitter:image': 'https://i.gadgets360cdn.com/large/samsung-galaxys24-ultra_1705477612346.jpg',
#       'article:publisher': 'https://www.facebook.com/Gadgets360/',
#       'publish-date': '2024-01-17T23:45:22+05:30',
#       'taboola:title': 'Samsung Galaxy S24 Ultra, Galaxy S24+, and Galaxy S24 First Look',
#       'taboola-category': 'gadgets',
#       'twitter:site': '@Gadgets360',
#       'msapplication-tap-highlight': 'no',
#       'news_keywords': 'galaxy unpacked,galaxy unpacked 2024,samsung,samsung galaxy s24,samsung galaxy s24 ultra,samsung galaxy s24 plus,android',
#       'twitter:title': 'Samsung Galaxy S24 Ultra, Galaxy S24+, and Galaxy S24 First Look',
#       'og:title': 'Samsung Galaxy S24 Ultra, Galaxy S24+, and Galaxy S24 First Look',
#       'twitter:app:id:ipad': '620437614',
#       'fb:pages': '307224649334491',
#       'article:author': 'https://facebook.com/harryjerry',
#       'apple-mobile-web-app-status-bar-style': 'black-translucent',
#       'twitter:app:name:ipad': 'Gadgets 360',
#       'viewport': 'width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no',
#       'twitter:description': 'Can Samsung redefine the flagship smartphone experience with AI?',
#       'apple-mobile-web-app-capable': 'yes',
#       'category': 'Gadgets',
#       'og:url': 'https://www.gadgets360.com/mobiles/reviews/samsung-galaxy-s24-ultra-plus-series-price-in-india-first-look-camera-specifications-4878627',
#       'al:android:app_name': 'Gadgets 360',
#       'twitter:app:name:iphone': 'Gadgets 360'}],
#     'cse_image': [{'src': 'https://i.gadgets360cdn.com/large/samsung-galaxys24-ultra_1705477612346.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S24 Ultra Review (In Progress) Digit.in',
#    'htmlTitle': '<b>Samsung Galaxy S24 Ultra Review</b> (In Progress) Digit.in',
#    'link': 'https://www.digit.in/reviews/mobile-phones/samsung-galaxy-s24-ultra-review-in-progress.html',
#    'displayLink': 'www.digit.in',
#    'snippet': 'Jan 22, 2024 ... This is an in-progress review of the Samsung Galaxy S24 Ultra.',
#    'htmlSnippet': 'Jan 22, 2024 <b>...</b> This is an in-progress <b>review</b> of the <b>Samsung Galaxy S24 Ultra</b>.',
#    'cacheId': 'pkDz3S49XTgJ',
#    'formattedUrl': 'https://www.digit.in/reviews/.../samsung-galaxy-s24-ultra-review-in-progres...',
#    'htmlFormattedUrl': 'https://www.digit.in/<b>review</b>s/.../<b>samsung</b>-<b>galaxy</b>-<b>s24</b>-<b>ultra</b>-<b>review</b>-in-progres...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSbXWfdPqZuIImkTEnZL_BLrA1JEMkzDYNP2E5vSsiTePEAnUnGK1pnHNU',
#       'width': '300',
#       'height': '168'}],
#     'metatags': [{'og:image': 'https://static.digit.in/Samsung-Galaxy-S24-Ultra-1280x720-1.jpg',
#       'og:image:width': '1280',
#       'article:published_time': '2024-01-22T17:00:00+05:30',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Digit',
#       'twitter:url': 'https://www.digit.in/reviews/mobile-phones/samsung-galaxy-s24-ultra-review-in-progress.html',
#       'twitter:label1': 'Written by',
#       'twitter:label2': 'Est. reading time',
#       'msapplication-tileimage': 'https://static.digit.in/favicon-1-300x300.png',
#       'og:description': 'This is an in-progress review of the Samsung Galaxy S24 Ultra.',
#       'twitter:creator': '@mithun_mohandas',
#       'og:image:secure_url': 'https://static.digit.in/Samsung-Galaxy-S24-Ultra-1280x720-1.jpg',
#       'article:publisher': 'https://www.facebook.com/thinkdigit',
#       'twitter:image': 'https://static.digit.in/Samsung-Galaxy-S24-Ultra-1280x720-1.jpg',
#       'twitter:data1': 'Mithun Mohandas',
#       'twitter:data2': '6 minutes',
#       'twitter:site': '@digitindia',
#       'article:modified_time': '2024-01-22T17:24:00+05:30',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy S24 Ultra Review (In Progress)',
#       'og:title': 'Samsung Galaxy S24 Ultra Review (In Progress)',
#       'og:image:height': '720',
#       'fb:pages': '110963532384',
#       'article:author': 'https://www.facebook.com/mithun.mohandas',
#       'fb:app_id': '243909795959629',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': 'This is an in-progress review of the Samsung Galaxy S24 Ultra.',
#       'og:locale': 'en',
#       'og:url': 'https://www.digit.in/reviews/mobile-phones/samsung-galaxy-s24-ultra-review-in-progress.html'}],
#     'cse_image': [{'src': 'https://static.digit.in/Samsung-Galaxy-S24-Ultra-1280x720-1.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S23 Ultra review: indomitable showman | TechRadar',
#    'htmlTitle': '<b>Samsung Galaxy</b> S23 <b>Ultra review</b>: indomitable showman | TechRadar',
#    'link': 'https://www.techradar.com/reviews/samsung-galaxy-s23-ultra',
#    'displayLink': 'www.techradar.com',
#    'snippet': 'Feb 13, 2023 ... Should I buy it? Also consider; How I tested. Samsung Galaxy S23 Ultra: Two-minute review. The\xa0...',
#    'htmlSnippet': 'Feb 13, 2023 <b>...</b> Should I buy it? Also consider; How I tested. <b>Samsung Galaxy</b> S23 <b>Ultra</b>: Two-minute <b>review</b>. The&nbsp;...',
#    'formattedUrl': 'https://www.techradar.com/reviews/samsung-galaxy-s23-ultra',
#    'htmlFormattedUrl': 'https://www.techradar.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-s23-<b>ultra</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSt8Fx0Z2YLr8aHozMAlRUR34wttD_UV5bHE3mgr5hVV8JT2NvGACE7xnY',
#       'width': '300',
#       'height': '168'}],
#     'imageobject': [{'width': '920',
#       'url': 'https://cdn.mos.cms.futurecdn.net/W3UHbt4p2sgWhEkcEatDg8.jpg',
#       'height': '456'}],
#     'metatags': [{'p:domain_verify': '10329f1fd4d0a2cd5c0d3b3b809cb4cd',
#       'og:image': 'https://cdn.mos.cms.futurecdn.net/hXssEsAfPKxYekpDf7srxW-1200-80.jpg',
#       'omg-verify-v1': '1036697-2d2c9025-5430-4e79-8349-e8c1c926dd73',
#       'og:image:width': '1200',
#       'article:published_time': '2023-02-01T18:00:48Z',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#090E21',
#       'og:site_name': 'TechRadar',
#       'taboola:url': 'https://www.techradar.com/reviews/samsung-galaxy-s23-ultra',
#       'parsely-author': 'Alex Walker-Todd',
#       'msapplication-tileimage': 'https://vanilla.futurecdn.net/techradar/876321/apple-touch-icon.png',
#       'og:description': 'Upping the ante on the already excellent',
#       'twitter:creator': '@TechRadar',
#       'article:publisher': 'https://www.facebook.com/TechRadar',
#       'twitter:image': 'https://cdn.mos.cms.futurecdn.net/hXssEsAfPKxYekpDf7srxW-1200-80.jpg',
#       'pub_date': '2023-02-01T18:00:48+00:00',
#       'parsely-type': 'post',
#       'twitter:site': '@TechRadar',
#       'article:modified_time': '2023-02-13T09:36:41Z',
#       'parsely-link': 'https://www.techradar.com/reviews/samsung-galaxy-s23-ultra',
#       'parsely-image-url': 'https://cdn.mos.cms.futurecdn.net/hXssEsAfPKxYekpDf7srxW.jpg',
#       'parsely-section': 'Samsung Galaxy Phones',
#       'botify-site-verification': 'xkNFqB6l1qBl8BEqMjQvrHuYinhxlJVe',
#       'twitter:account_id': '15560223',
#       'msapplication-tilecolor': '#000000',
#       'lomadee-verification': '22816996',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy S23 Ultra review: indomitable showman',
#       'parsely-post-id': 'zScwegLWAMSW7ih6EA5Cnf',
#       'msvalidate.01': 'CC462E6DF91492086145CA5EBDCB615E',
#       'og:title': 'Samsung Galaxy S23 Ultra review: indomitable showman',
#       'parsely-title': 'Samsung Galaxy S23 Ultra review: indomitable showman',
#       'parsely-pub-date': '2023-02-01T18:00:48Z',
#       'parsely-tags': 'Category: Samsung Galaxy Phones,Category: Phones,Category: Review,Android,Samsung,Samsung Galaxy S23,Samsung Galaxy S23 Ultra,Samsung Galaxy S23 Ultra,Samsung Galaxy S23 Ultra Pre-Order,Samsung Galaxy S23 Ultra,Samsung Galaxy S23 Ultra Pre-Order,van_sticky_side_nav,awardrecommended,type_review,channel_phones,serversidehawk,enhanced-review',
#       'fb:app_id': '235441786508054',
#       'viewport': 'width=device-width,minimum-scale=1,initial-scale=1',
#       'twitter:description': 'Upping the ante on the already excellent',
#       'og:url': 'https://www.techradar.com/reviews/samsung-galaxy-s23-ultra'}],
#     'cse_image': [{'src': 'https://cdn.mos.cms.futurecdn.net/hXssEsAfPKxYekpDf7srxW-1200-80.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S22 Ultra review | TechRadar',
#    'htmlTitle': '<b>Samsung Galaxy</b> S22 <b>Ultra review</b> | TechRadar',
#    'link': 'https://www.techradar.com/reviews/samsung-galaxy-s22-ultra-review',
#    'displayLink': 'www.techradar.com',
#    'snippet': "Feb 1, 2023 ... Our Samsung Galaxy S22 Ultra review found a big, powerful, and attractive Android phone (if you like them monolithic). It's super-versatile,\xa0...",
#    'htmlSnippet': 'Feb 1, 2023 <b>...</b> Our <b>Samsung Galaxy</b> S22 <b>Ultra review</b> found a big, powerful, and attractive Android phone (if you like them monolithic). It&#39;s super-versatile,&nbsp;...',
#    'formattedUrl': 'https://www.techradar.com/reviews/samsung-galaxy-s22-ultra-review',
#    'htmlFormattedUrl': 'https://www.techradar.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-s22-<b>ultra</b>-<b>review</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSQcaoE4ie8vUqXSi703ZAjyI8np3jtnOoYsIIMrUHWoQK9iNIrwW61OlE',
#       'width': '299',
#       'height': '169'}],
#     'imageobject': [{'width': '920',
#       'url': 'https://cdn.mos.cms.futurecdn.net/N2ChWZCYLCsK5UPoyvApci.png',
#       'height': '456'}],
#     'metatags': [{'p:domain_verify': '10329f1fd4d0a2cd5c0d3b3b809cb4cd',
#       'og:image': 'https://cdn.mos.cms.futurecdn.net/X35xUexSBhzheDhDbDCv34-1200-80.jpg',
#       'omg-verify-v1': '1036697-2d2c9025-5430-4e79-8349-e8c1c926dd73',
#       'og:image:width': '1200',
#       'article:published_time': '2022-02-25T15:26:57Z',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#090E21',
#       'og:site_name': 'TechRadar',
#       'taboola:url': 'https://www.techradar.com/reviews/samsung-galaxy-s22-ultra-review',
#       'parsely-author': 'Lance Ulanoff',
#       'msapplication-tileimage': 'https://vanilla.futurecdn.net/techradar/876321/apple-touch-icon.png',
#       'og:description': 'The Samsung Galaxy S22 Ultra enters the Note zone',
#       'twitter:creator': '@TechRadar',
#       'article:publisher': 'https://www.facebook.com/TechRadar',
#       'twitter:image': 'https://cdn.mos.cms.futurecdn.net/X35xUexSBhzheDhDbDCv34-1200-80.jpg',
#       'pub_date': '2022-02-25T15:26:57+00:00',
#       'parsely-type': 'post',
#       'twitter:site': '@TechRadar',
#       'article:modified_time': '2023-02-01T18:37:44Z',
#       'parsely-link': 'https://www.techradar.com/reviews/samsung-galaxy-s22-ultra-review',
#       'parsely-image-url': 'https://cdn.mos.cms.futurecdn.net/X35xUexSBhzheDhDbDCv34.jpg',
#       'parsely-section': 'Samsung Galaxy Phones',
#       'botify-site-verification': 'xkNFqB6l1qBl8BEqMjQvrHuYinhxlJVe',
#       'twitter:account_id': '15560223',
#       'msapplication-tilecolor': '#000000',
#       'lomadee-verification': '22816996',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy S22 Ultra review',
#       'parsely-post-id': 'vsaabmbxhRS8EZfpHG63AD',
#       'msvalidate.01': 'CC462E6DF91492086145CA5EBDCB615E',
#       'og:title': 'Samsung Galaxy S22 Ultra review',
#       'parsely-title': 'Samsung Galaxy S22 Ultra review',
#       'parsely-pub-date': '2022-02-25T15:26:57Z',
#       'parsely-tags': 'Category: Samsung Galaxy Phones,Category: Phones,Category: Review,Samsung Galaxy S22 Ultra,Samsung,mobile,5G,Samsung Galaxy Unpacked 2022,review,Samsung Galaxy S22 Ultra,Samsung Galaxy S22 Ultra,type_review,channel_phones,no-in-article-video,awardrecommended,big-curated-middle,exclude-from-homepage,van_sticky_side_nav,serversidehawk,videoarticle,enhanced-review',
#       'fb:app_id': '235441786508054',
#       'viewport': 'width=device-width,minimum-scale=1,initial-scale=1',
#       'twitter:description': 'The Samsung Galaxy S22 Ultra enters the Note zone',
#       'og:url': 'https://www.techradar.com/reviews/samsung-galaxy-s22-ultra-review'}],
#     'cse_image': [{'src': 'https://cdn.mos.cms.futurecdn.net/X35xUexSBhzheDhDbDCv34-1200-80.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S24+ Review | PCMag',
#    'htmlTitle': '<b>Samsung Galaxy</b> S24+ <b>Review</b> | PCMag',
#    'link': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-plus',
#    'displayLink': 'www.pcmag.com',
#    'snippet': '4 days ago ... ... S24 Ultra. For a full breakdown of how the AI features fared, check out our Galaxy S24 Ultra review. Below are just a few examples. Chat\xa0...',
#    'htmlSnippet': '4 days ago <b>...</b> ... <b>S24 Ultra</b>. For a full breakdown of how the AI features fared, check out our <b>Galaxy S24 Ultra review</b>. Below are just a few examples. Chat&nbsp;...',
#    'cacheId': 'r35SN-NKtPwJ',
#    'formattedUrl': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-plus',
#    'htmlFormattedUrl': 'https://www.pcmag.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-<b>s24</b>-plus',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcR_-6D4gE4PMJm9Y_5tIk7sTK0WeQX8JQ5qdpfumcAu9p4BNyvGMG8kDCEH',
#       'width': '299',
#       'height': '168'}],
#     'metatags': [{'application-name': 'PCMag',
#       'og:image': 'https://i.pcmag.com/imagery/reviews/02ImGZ9x4e5CRr5LXDsL1eE-17.fit_lim.size_1200x630.v1706724975.jpg',
#       'og:type': 'article',
#       'og:image:width': '1200',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Samsung Galaxy S24+ Review',
#       'og:site_name': 'PCMAG',
#       'twitter:url': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-plus',
#       'og:title': 'Samsung Galaxy S24+ Review',
#       'og:image:height': '630',
#       'og:description': 'The Samsung Galaxy S24+ is a powerful Android phone for the masses thanks to its high-quality hardware, outstanding software, and top-tier performance.',
#       'twitter:image': 'https://i.pcmag.com/imagery/reviews/02ImGZ9x4e5CRr5LXDsL1eE-17.fit_lim.size_1200x630.v1706724975.jpg',
#       'zd_ptax_version': 'PCMagV3',
#       'fb:app_id': '141810985954037',
#       'twitter:site': '@pcmag',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': 'The Samsung Galaxy S24+ is a powerful Android phone for the masses thanks to its high-quality hardware, outstanding software, and top-tier performance.',
#       'zd_ptax': 'samsung,computers-electronics,mobile-phones',
#       'og:url': 'https://www.pcmag.com/reviews/samsung-galaxy-s24-plus',
#       'twitter:account_id': '15066271'}],
#     'cse_image': [{'src': 'https://i.pcmag.com/imagery/reviews/02ImGZ9x4e5CRr5LXDsL1eE-17.fit_lim.size_1200x630.v1706724975.jpg'}],
#     'listitem': [{'item': 'Home', 'name': 'Home', 'position': '1'},
#      {'item': 'Reviews', 'name': 'Reviews', 'position': '2'},
#      {'item': 'Mobile Phones', 'name': 'Mobile Phones', 'position': '3'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S22 review: a small-form wonder',
#    'htmlTitle': '<b>Samsung Galaxy</b> S22 <b>review</b>: a small-form wonder',
#    'link': 'https://www.techradar.com/reviews/samsung-galaxy-s22-review',
#    'displayLink': 'www.techradar.com',
#    'snippet': 'Feb 1, 2023 ... Samsung Galaxy S24 Ultra review · Apple Vision Pro · Galaxy Ring · Samsung ... review, and our full Samsung Galaxy S23 Ultra review for more\xa0...',
#    'htmlSnippet': 'Feb 1, 2023 <b>...</b> <b>Samsung Galaxy S24 Ultra review</b> &middot; Apple Vision Pro &middot; Galaxy Ring &middot; Samsung ... review, and our full Samsung Galaxy S23 Ultra review for more&nbsp;...',
#    'formattedUrl': 'https://www.techradar.com/reviews/samsung-galaxy-s22-review',
#    'htmlFormattedUrl': 'https://www.techradar.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-s22-<b>review</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTjSapxgjxjKaALFH_ev2HZLkPo1E1BNmorV8iq2xg8WhxQ5bF7gpAiMQrx',
#       'width': '300',
#       'height': '168'}],
#     'imageobject': [{'width': '920',
#       'url': 'https://cdn.mos.cms.futurecdn.net/XFXCfQ56eChCihVSNjEBXE.jpg',
#       'height': '456'}],
#     'metatags': [{'p:domain_verify': '10329f1fd4d0a2cd5c0d3b3b809cb4cd',
#       'og:image': 'https://cdn.mos.cms.futurecdn.net/eFCgRTrSePocfCjEYDYciK-1200-80.jpg',
#       'omg-verify-v1': '1036697-2d2c9025-5430-4e79-8349-e8c1c926dd73',
#       'og:image:width': '1200',
#       'article:published_time': '2022-03-30T16:17:24Z',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#090E21',
#       'og:site_name': 'TechRadar',
#       'taboola:url': 'https://www.techradar.com/reviews/samsung-galaxy-s22-review',
#       'parsely-author': 'Lance Ulanoff',
#       'msapplication-tileimage': 'https://vanilla.futurecdn.net/techradar/876321/apple-touch-icon.png',
#       'og:description': 'Small, brimming with upgrades, and eminently useful',
#       'twitter:creator': '@TechRadar',
#       'article:publisher': 'https://www.facebook.com/TechRadar',
#       'twitter:image': 'https://cdn.mos.cms.futurecdn.net/eFCgRTrSePocfCjEYDYciK-1200-80.jpg',
#       'pub_date': '2022-03-30T16:17:24+00:00',
#       'parsely-type': 'post',
#       'twitter:site': '@TechRadar',
#       'article:modified_time': '2023-02-01T18:08:13Z',
#       'parsely-link': 'https://www.techradar.com/reviews/samsung-galaxy-s22-review',
#       'parsely-image-url': 'https://cdn.mos.cms.futurecdn.net/eFCgRTrSePocfCjEYDYciK.jpg',
#       'parsely-section': 'Samsung Galaxy Phones',
#       'botify-site-verification': 'xkNFqB6l1qBl8BEqMjQvrHuYinhxlJVe',
#       'twitter:account_id': '15560223',
#       'msapplication-tilecolor': '#000000',
#       'lomadee-verification': '22816996',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy S22 review: a small-form wonder',
#       'parsely-post-id': 'ZNBf372pvd3aBSgj9gexpf',
#       'msvalidate.01': 'CC462E6DF91492086145CA5EBDCB615E',
#       'og:title': 'Samsung Galaxy S22 review: a small-form wonder',
#       'parsely-title': 'Samsung Galaxy S22 review: a small-form wonder',
#       'parsely-pub-date': '2022-03-30T16:17:24Z',
#       'parsely-tags': 'Category: Samsung Galaxy Phones,Category: Phones,Category: Review,Samsung,Samsung Galaxy S22,5G,mobile,Samsung Galaxy S22,Samsung Galaxy S22,type_review,channel_phones,exclude-from-homepage,serversidehawk,enhanced-review',
#       'fb:app_id': '235441786508054',
#       'viewport': 'width=device-width,minimum-scale=1,initial-scale=1',
#       'twitter:description': 'Small, brimming with upgrades, and eminently useful',
#       'og:url': 'https://www.techradar.com/reviews/samsung-galaxy-s22-review'}],
#     'cse_image': [{'src': 'https://cdn.mos.cms.futurecdn.net/eFCgRTrSePocfCjEYDYciK-1200-80.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy Pro review | TechRadar',
#    'htmlTitle': '<b>Samsung Galaxy</b> Pro <b>review</b> | TechRadar',
#    'link': 'https://www.techradar.com/reviews/phones/mobile-phones/samsung-galaxy-pro-961384/review',
#    'displayLink': 'www.techradar.com',
#    'snippet': 'Jul 18, 2011 ... Samsung Galaxy S24 Ultra review · Apple Vision Pro · Galaxy Ring · Samsung Galaxy S24 hands-on review · Wordle hints · Best VPN. When you\xa0...',
#    'htmlSnippet': 'Jul 18, 2011 <b>...</b> <b>Samsung Galaxy S24 Ultra review</b> &middot; Apple Vision Pro &middot; Galaxy Ring &middot; Samsung Galaxy S24 hands-on review &middot; Wordle hints &middot; Best VPN. When you&nbsp;...',
#    'cacheId': 'LCISchdA1agJ',
#    'formattedUrl': 'https://www.techradar.com/reviews/phones/mobile.../samsung-galaxy.../revi...',
#    'htmlFormattedUrl': 'https://www.techradar.com/<b>review</b>s/phones/mobile.../<b>samsung</b>-<b>galaxy</b>.../<b>revi</b>...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTmcXGU0zRntskh0H08S5WA3ifptIlzW5bqdw3e3qaZ_-TEot68_HbaS-o',
#       'width': '259',
#       'height': '194'}],
#     'imageobject': [{'width': '920',
#       'url': 'https://cdn.mos.cms.futurecdn.net/be8ff8c4ec5162d9ffdfbbf7f2a328d2.jpg',
#       'height': '456'}],
#     'metatags': [{'p:domain_verify': '10329f1fd4d0a2cd5c0d3b3b809cb4cd',
#       'og:image': 'https://cdn.mos.cms.futurecdn.net/be8ff8c4ec5162d9ffdfbbf7f2a328d2-1200-80.jpg',
#       'omg-verify-v1': '1036697-2d2c9025-5430-4e79-8349-e8c1c926dd73',
#       'og:image:width': '1200',
#       'article:published_time': '2011-07-18T15:22:00.198Z',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#090E21',
#       'og:site_name': 'TechRadar',
#       'taboola:url': 'https://www.techradar.com/reviews/phones/mobile-phones/samsung-galaxy-pro-961384/review',
#       'parsely-author': 'Sandra Vogel',
#       'msapplication-tileimage': 'https://vanilla.futurecdn.net/techradar/876321/apple-touch-icon.png',
#       'og:description': 'Cheap as chips Android with a QWERTY keyboard',
#       'twitter:creator': '@TechRadar',
#       'article:publisher': 'https://www.facebook.com/TechRadar',
#       'twitter:image': 'https://cdn.mos.cms.futurecdn.net/be8ff8c4ec5162d9ffdfbbf7f2a328d2-1200-80.jpg',
#       'pub_date': '2011-07-18T15:22:00+00:00',
#       'parsely-type': 'post',
#       'twitter:site': '@TechRadar',
#       'article:modified_time': '2011-07-18T15:22:00.198Z',
#       'parsely-link': 'https://www.techradar.com/reviews/phones/mobile-phones/samsung-galaxy-pro-961384/review',
#       'parsely-image-url': 'https://cdn.mos.cms.futurecdn.net/be8ff8c4ec5162d9ffdfbbf7f2a328d2.jpg',
#       'parsely-section': 'Samsung Galaxy Phones',
#       'botify-site-verification': 'xkNFqB6l1qBl8BEqMjQvrHuYinhxlJVe',
#       'twitter:account_id': '15560223',
#       'msapplication-tilecolor': '#000000',
#       'lomadee-verification': '22816996',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy Pro review',
#       'parsely-post-id': 'YSQZiMhXJiJvoZbwLM2ni',
#       'msvalidate.01': 'CC462E6DF91492086145CA5EBDCB615E',
#       'og:title': 'Samsung Galaxy Pro review',
#       'parsely-title': 'Samsung Galaxy Pro review',
#       'parsely-pub-date': '2011-07-18T15:22:00.198Z',
#       'parsely-tags': 'Category: Samsung Galaxy Phones,Category: Phones,Category: Review,Samsung,mobile phone,cell phone,smartphone,Galaxy Pro,TechRadar ,allow-comments,serversidehawk,enhanced-review',
#       'fb:app_id': '235441786508054',
#       'viewport': 'width=device-width,minimum-scale=1,initial-scale=1',
#       'twitter:description': 'Cheap as chips Android with a QWERTY keyboard',
#       'og:url': 'https://www.techradar.com/reviews/phones/mobile-phones/samsung-galaxy-pro-961384/review'}],
#     'cse_image': [{'src': 'https://cdn.mos.cms.futurecdn.net/be8ff8c4ec5162d9ffdfbbf7f2a328d2-1200-80.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Samsung Galaxy S21 Ultra review: a top phone that's been replaced ...",
#    'htmlTitle': '<b>Samsung Galaxy</b> S21 <b>Ultra review</b>: a top phone that&#39;s been replaced ...',
#    'link': 'https://www.techradar.com/reviews/samsung-galaxy-s21-ultra-review',
#    'displayLink': 'www.techradar.com',
#    'snippet': "Jul 5, 2021 ... When we wrote this Samsung Galaxy S21 Ultra review, it was the company's new 'everything phone' with more cameras, beefier specs,\xa0...",
#    'htmlSnippet': 'Jul 5, 2021 <b>...</b> When we wrote this <b>Samsung Galaxy</b> S21 <b>Ultra review</b>, it was the company&#39;s new &#39;everything phone&#39; with more cameras, beefier specs,&nbsp;...',
#    'formattedUrl': 'https://www.techradar.com/reviews/samsung-galaxy-s21-ultra-review',
#    'htmlFormattedUrl': 'https://www.techradar.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-s21-<b>ultra</b>-<b>review</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ3gby2TsNBASdEUrJQo2KxTsgixHteP0vqjkuf1MAb4iUCQcdzBr3QdrM',
#       'width': '300',
#       'height': '168'}],
#     'imageobject': [{'width': '920',
#       'url': 'https://cdn.mos.cms.futurecdn.net/RT7jeVnZzEcY3KYjsessr7.jpg',
#       'height': '456'}],
#     'metatags': [{'p:domain_verify': '10329f1fd4d0a2cd5c0d3b3b809cb4cd',
#       'og:image': 'https://cdn.mos.cms.futurecdn.net/Q2eW2m6uASnYsWRn5m7mr4-1200-80.jpg',
#       'omg-verify-v1': '1036697-2d2c9025-5430-4e79-8349-e8c1c926dd73',
#       'og:image:width': '1200',
#       'article:published_time': '2021-07-05T10:29:04Z',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#090E21',
#       'og:site_name': 'TechRadar',
#       'taboola:url': 'https://www.techradar.com/reviews/samsung-galaxy-s21-ultra-review',
#       'parsely-author': 'Matt Swider',
#       'msapplication-tileimage': 'https://vanilla.futurecdn.net/techradar/876321/apple-touch-icon.png',
#       'og:description': 'The Galaxy S21 Ultra is as good as it looks',
#       'twitter:creator': '@TechRadar',
#       'article:publisher': 'https://www.facebook.com/TechRadar',
#       'twitter:image': 'https://cdn.mos.cms.futurecdn.net/Q2eW2m6uASnYsWRn5m7mr4-1200-80.jpg',
#       'pub_date': '2021-07-05T10:29:04+00:00',
#       'parsely-type': 'post',
#       'twitter:site': '@TechRadar',
#       'article:modified_time': '2021-07-05T10:29:04Z',
#       'parsely-link': 'https://www.techradar.com/reviews/samsung-galaxy-s21-ultra-review',
#       'parsely-image-url': 'https://cdn.mos.cms.futurecdn.net/Q2eW2m6uASnYsWRn5m7mr4.jpg',
#       'parsely-section': 'Samsung Galaxy Phones',
#       'botify-site-verification': 'xkNFqB6l1qBl8BEqMjQvrHuYinhxlJVe',
#       'twitter:account_id': '15560223',
#       'msapplication-tilecolor': '#000000',
#       'lomadee-verification': '22816996',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy S21 Ultra review',
#       'parsely-post-id': 'BjnufFnVBr35oisgodJsLm',
#       'msvalidate.01': 'CC462E6DF91492086145CA5EBDCB615E',
#       'og:title': 'Samsung Galaxy S21 Ultra review',
#       'parsely-title': 'Samsung Galaxy S21 Ultra review',
#       'parsely-pub-date': '2021-07-05T10:29:04Z',
#       'parsely-tags': 'Category: Samsung Galaxy Phones,Category: Phones,Category: Review,Samsung Galaxy S21 Ultra,Samsung,Samsung Galaxy S21 Ultra,Samsung Galaxy S21 Ultra,type_review,channel_phones,awardrecommended,exclude-from-homepage,serversidehawk,videoarticle,enhanced-review',
#       'fb:app_id': '235441786508054',
#       'viewport': 'width=device-width,minimum-scale=1,initial-scale=1',
#       'twitter:description': 'The Galaxy S21 Ultra is as good as it looks',
#       'og:url': 'https://www.techradar.com/reviews/samsung-galaxy-s21-ultra-review'}],
#     'cse_image': [{'src': 'https://cdn.mos.cms.futurecdn.net/Q2eW2m6uASnYsWRn5m7mr4-1200-80.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Samsung Galaxy S20 review | TechRadar',
#    'htmlTitle': '<b>Samsung Galaxy</b> S20 <b>review</b> | TechRadar',
#    'link': 'https://www.techradar.com/reviews/samsung-galaxy-s20-full-review',
#    'displayLink': 'www.techradar.com',
#    'snippet': 'May 3, 2021 ... Samsung Galaxy S24 Ultra review · Apple Vision Pro · Galaxy Ring · Samsung Galaxy S24 hands-on review · Wordle hints · Best VPN. When you\xa0...',
#    'htmlSnippet': 'May 3, 2021 <b>...</b> <b>Samsung Galaxy S24 Ultra review</b> &middot; Apple Vision Pro &middot; Galaxy Ring &middot; Samsung Galaxy S24 hands-on review &middot; Wordle hints &middot; Best VPN. When you&nbsp;...',
#    'formattedUrl': 'https://www.techradar.com/reviews/samsung-galaxy-s20-full-review',
#    'htmlFormattedUrl': 'https://www.techradar.com/<b>review</b>s/<b>samsung</b>-<b>galaxy</b>-s20-full-<b>review</b>',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQHXy_zcNRbGIO7f-W2VWU6_OYpQPlkapQOc6AZc_QtsKLeOhaUlQMSIbad',
#       'width': '300',
#       'height': '168'}],
#     'imageobject': [{'width': '920',
#       'url': 'https://cdn.mos.cms.futurecdn.net/kpoSe2Jmn4ghwMAxnBtdid.jpg',
#       'height': '456'}],
#     'metatags': [{'p:domain_verify': '10329f1fd4d0a2cd5c0d3b3b809cb4cd',
#       'og:image': 'https://cdn.mos.cms.futurecdn.net/v4rRzguZFHmGQAdC9NNtBm-1200-80.jpg',
#       'omg-verify-v1': '1036697-2d2c9025-5430-4e79-8349-e8c1c926dd73',
#       'og:image:width': '1200',
#       'article:published_time': '2021-05-04T02:23:18Z',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#090E21',
#       'og:site_name': 'TechRadar',
#       'taboola:url': 'https://www.techradar.com/reviews/samsung-galaxy-s20-full-review',
#       'parsely-author': 'James Peckham',
#       'msapplication-tileimage': 'https://vanilla.futurecdn.net/techradar/876321/apple-touch-icon.png',
#       'og:description': '5G, a 120Hz display and more debut on the Galaxy S20',
#       'twitter:creator': '@TechRadar',
#       'article:publisher': 'https://www.facebook.com/TechRadar',
#       'twitter:image': 'https://cdn.mos.cms.futurecdn.net/v4rRzguZFHmGQAdC9NNtBm-1200-80.jpg',
#       'pub_date': '2021-05-04T02:23:18+00:00',
#       'parsely-type': 'post',
#       'twitter:site': '@TechRadar',
#       'article:modified_time': '2021-05-04T02:23:18Z',
#       'parsely-link': 'https://www.techradar.com/reviews/samsung-galaxy-s20-full-review',
#       'parsely-image-url': 'https://cdn.mos.cms.futurecdn.net/v4rRzguZFHmGQAdC9NNtBm.jpg',
#       'parsely-section': 'Samsung Galaxy Phones',
#       'botify-site-verification': 'xkNFqB6l1qBl8BEqMjQvrHuYinhxlJVe',
#       'twitter:account_id': '15560223',
#       'msapplication-tilecolor': '#000000',
#       'lomadee-verification': '22816996',
#       'og:type': 'article',
#       'twitter:title': 'Samsung Galaxy S20 review',
#       'parsely-post-id': 'Hnps6N6na4qmr7Si6hHe67',
#       'msvalidate.01': 'CC462E6DF91492086145CA5EBDCB615E',
#       'og:title': 'Samsung Galaxy S20 review',
#       'parsely-title': 'Samsung Galaxy S20 review',
#       'parsely-pub-date': '2021-05-04T02:23:18Z',
#       'parsely-tags': 'Category: Samsung Galaxy Phones,Category: Phones,Category: Review,Samsung,5G,Samsung Galaxy S20,Samsung Galaxy S11,Samsung Galaxy S20 5G,Samsung Galaxy S20 5G,Samsung Galaxy S20,Samsung Galaxy S20 5G,Samsung Galaxy S20,type_review,channel_phones,awardrecommended,exclude-from-homepage,serversidehawk,enhanced-review',
#       'fb:app_id': '235441786508054',
#       'viewport': 'width=device-width,minimum-scale=1,initial-scale=1',
#       'twitter:description': '5G, a 120Hz display and more debut on the Galaxy S20',
#       'og:url': 'https://www.techradar.com/reviews/samsung-galaxy-s20-full-review'}],
#     'cse_image': [{'src': 'https://cdn.mos.cms.futurecdn.net/v4rRzguZFHmGQAdC9NNtBm-1200-80.jpg'}]}}]}

# %%
import os

# %%
def search_google(query):
    google_api_key = os.environ.get('GOOGLE_API_KEY')
    google_search = f'https://www.googleapis.com/customsearch/v1?key={google_api_key}&cx=16bf42430283e4cb5&q={query}&exactTerms=review'
    google_search_response = requests.get(google_search)
    if google_search_response.status_code != 200:
        return None
    return google_search_response.json()

# %%
class Reviews:
    def __init__(self):
        self.google_api_key = os.environ.get('GOOGLE_API_KEY')
        self.cx = '16bf42430283e4cb5'
        self.extract_review = {
            'tomsguide': {
                'element': 'p',
                'attrs': {'class': 'pretty-verdict'}
            },
            'techradar': {
                'element': 'div',
                'attrs': {'class': 'pretty-verdict'}
            
            },
            'digit': {
                'element': 'article',
            },
            'weartesters': {
                'element': 'div',
                'attrs': {'class': 'entry-content'}
            },
            'skincarevilla': {
                'element': 'article'
            },
            'thebeautyinsideout': {
                'element': 'div',
                'attrs': {'id': 'primary'}
            },
            'digitaltrends': {
                'element': 'article'
            },
            'engadget': {
                'element': 'div',
                'attrs': {'class': 'caas-content'}
            },
            'anandtech': {
                'element': 'div',
                'attrs': {'class': 'articleContent'}
            },
            'tomshardware': {
                'element': 'div',
                'attrs': {'class': 'pretty-verdict'}
            },
            'techspot': {
                'element': 'div',
                'attrs': {'class': 'articleBody'}
            },
            'cnet': {
                'element': 'meta',
                'attrs': {'content': 'article'}
            },
            'theverge': {
                'element': 'aside'
            },
            'soleracks': {
                'element': 'div',
                'attrs': {'class': 'fusion-content-boxes'}
            },
            'shoesguidance': {
                'element': 'div',
                'attrs': {'class': 'entry-content'}
            },
            'laptopmag': {
                'element': 'div',
                'attrs': {'class': 'pretty-verdict'}
            }
        }
    
    def search_google(self, query):
        query = query.lower()
        google_search = f'https://www.googleapis.com/customsearch/v1?key={self.google_api_key}&cx={self.cx}&q={query}&exactTerms=review&excludeTerms=page'
        google_search_response = requests.get(google_search)
        if google_search_response.status_code != 200:
            return None
        return google_search_response.json()

    def get_reviews(self, query):
        google_search_response = self.search_google(query)
        if google_search_response is None:
            return None
        items = google_search_response.get('items')
        if items is None:
            return None
        reviews = []
        for item in items:
            for website, review_tree in self.extract_review.items():
                if website in item['link']:
                    headers = {'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Mobile Safari/537.36 Edg/121.0.0.0', 
                               'referer': item['link']}
                    response = requests.get(item['link'], headers=headers)
                    print(response.status_code)
                    # print(response.text)
                    soup = BeautifulSoup(response.text, 'html.parser')
                    attrs = review_tree.get('attrs')
                    if attrs:
                        review = soup.find_all(review_tree['element'], review_tree['attrs'])
                    else:
                        review = soup.find_all(review_tree['element'])
                    print(item['link'])
                    for i in review:
                        print(i.text)
                    # print(item['link'], review[0].text)
                    # if review:
                    #     reviews.append({
                    #         'website': website,
                    #         'review': review[0].text
                    #     })
                    # break
        return reviews

# %%
search = Reviews()

# %%
search.get_reviews('Macbook Pro M3')
# Out:
# 200
# https://www.techradar.com/reviews/apple-macbook-pro-16-inch-2023
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
#
# The MacBook Pro 16-inch (2023) is another triumph from Apple. The company is clearly comfortable with making its own chips, and while the 2023 model isn’t the game-changing revelation that the 2021 model was, it remains an incredibly powerful workstation laptop with an industry-leading screen and battery life. TODAY'S BEST DEALS£2,349.97at Amazon(512GB)£2,379.97at Amazon(512GB)£2,728at Amazon(Black)
#
# Pros
# +New M2 Pro and M2 Max chips+Over 20 hours battery life+Still the best screen on a laptop
# Cons
# -Expensive-Bulky
# 200
# https://www.techradar.com/reviews/apple-macbook-pro-14-inch-2023
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
#
# The MacBook Pro 14-inch (2023) is a fantastic mobile workstation that brings the power of the new M2 Pro and M2 Max chips to a compact and portable laptop. It keeps the same design as the 2021 model, but that's no bad thing given the brilliant screen and solid build quality. TODAY'S BEST DEALSCheck Amazon
#
# Pros
# +New M2 Pro and M2 Max chips+Almost 20-hour battery life+The best screen on a laptop
# Cons
# -Expensive-Price rise for UK and Australia
# 200
# https://www.techradar.com/reviews/apple-macbook-air-15-inch-2023-review
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
# The Apple MacBook Air 15-inch (2023) is essentially just a larger MacBook Air 13-inch – and that's both a good and bad thing. It has a stunning design, a brilliant screen, and possibly the best speaker setup you'll find in a laptop. However, the bump in screen size means it's less portable – one of the key selling points of the Air line – while anyone hoping for a more ambitious upgrade than just more screen real estate may be disappointed. TODAY'S BEST DEALS£1,269at Amazon£1,269at Amazon£1,269at Amazon
#
# Pros
# +Big screen+Slimline design+Surprisingly good price
# Cons
# -Same internal specs as a 13-inch model-Less portable than 13-inch model
# 200
# https://www.techradar.com/reviews/apple-macbook-pro-16-inch-2021
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
#
# The MacBook Pro 16-inch (2021) is one of the best laptops creative professionals can buy, thanks to its brilliant performance, stunning screen and long battery life. However, it is large and heavy, which is why the 14-inch MacBook Pro may be a better buy, unless you want the larger screen and longer battery life. TODAY'S BEST DEALS£1,599.97at Laptops Direct(512GB)£2,199at Amazon(512GB)£2,399at very.co.uk
#
# Pros
# +Excellent performance+Stunning mini-LED display+Extremely long battery life+Plenty of ports
# Cons
# -Large-Heavy-Expensive
# 200
# https://www.techradar.com/reviews/apple-macbook-pro-13-inch-m2-2022
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
# The Apple MacBook Pro 13-inch (M2, 2022) comes with Apple's latest M2 chip and offers excellent performance and battery life. However, there's no new design here, and with the new MacBook Air snapping at its heels, this laptop feels a bit redundant in some aspects. TODAY'S BEST DEALS£1,199at Currys(13.3-inch)£1,299.97at Laptops Direct(Space Grey)£1,408.98at Ebuyer
#
# Pros
# +M2 chip is a brilliant performer+Excellent battery life+Almost silent in use+Can even play games
# Cons
# -No new design-Still only two Thunderbolt ports-720p webcam-New MacBook Air offers better value
# 200
# https://www.tomshardware.com/reviews/macbook-pro-14-16-m2-pro-max-2023
#
#
#
# Tom's Hardware Verdict
#
#
#
#
#
#
#
#
#
# The 14 and 16-inch MacBook Pros, with M2 Pro and M2 Max offer incredible power and long-lasting battery life. Add best-in-class speakers and gorgeous Mini-LED screens and you have some of the best laptops on the market, if you're willing to pay for their high price tags.
#
# Pros
# +Powerful performance+Long battery life+Best speakers on a laptop+Beautiful Mini-LED display+Color matching MagSafe charger for Space Gray
# Cons
# -Notch in display is distracting, with no facial recognition-RAM and SSD upgrades are very pricey
# 200
# https://www.techradar.com/reviews/apple-mac-mini-2023
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
#
# The Mac mini (2023) is by far the best mini PC you can buy right now. Apart from the design, Apple has improved its most affordable Mac by every metric: it’s more powerful, comes with an option for an even more powerful M2 Pro chip, and the price of its base model is cheaper than ever. If you’re looking for a compact PC to sit unobtrusively on your desk, in a studio, or even under a TV, this is an excellent choice – even die-hard Windows users may be tempted.  TODAY'S BEST DEALS£598at Amazon(256GB)£649at Argos£649at very.co.uk(256GB)
#
# Pros
# +More powerful than ever+Compact design+New lower price
# Cons
# -Not upgradable
# 200
# https://www.techradar.com/reviews/macbook-pro-14-inch-2021
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
#
# The MacBook Pro 14-inch (2021) is the best laptop for creative professionals you can buy right now. It offers amazing performance, even on battery, and comes with the best screen you’ll find on a laptop anywhere. For day-to-day use, this won’t be the laptop for you, but for video editors, programmers, music producers and photographers, you won’t get a better laptop. TODAY'S BEST DEALS£1,899at very.co.uk(Apple M1 Pro)Check Amazon
#
# Pros
# +Brilliant performance+Best screen on a laptop+Long battery life+Plenty of ports
# Cons
# -Screen may be a bit small for some-Overkill for regular users
# 200
# https://www.techradar.com/reviews/apple-macbook-air-m2-2022
#
#
#
# TechRadar Verdict
#
#
#
#
#
#
#
#
#
# The MacBook Air (M2, 2022) is Apple’s follow-up to the best laptop it ever made, and while it comes close, it doesn’t quite beat the previous model. It’s got a fantastic design, bigger screen and incredibly long battery life, but also a much higher price tag. Think of it more as a replacement for the 13-inch MacBook Pro, and it starts to make a lot more sense. TODAY'S BEST DEALS£1,029.99at Amazon(13.6-inch)£1,049at very.co.uk(13.6-inch)£1,099at John Lewis(13.6-inch)
#
# Pros
# +Great new design+Very good performance+Long battery life+Larger screen
# Cons
# -Much more expensive than previous model-New colors are a bit tame-Previous model is much better value
# 200
# https://www.laptopmag.com/reviews/storage/owc-envoy-pro-ex
#
#
#
# Laptop Mag Verdict
#
#
#
#
#
#
#
#
# Small, stylish and blazing fast, the OWC Envoy Pro EX external SSD can copy files in the blink of an eye.
#
# Pros
# +Small and durable design+Bus-powered+Blazing fast read and write speeds
# Cons
# -Expensive
# []
